# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**2

def left_riem_sum(delta_x,a, b, n):
    sum = 0
    i = 0
    while i < n:
        x_i = a + i * delta_x
        sum += f(x_i)
        i += 1
    return sum * delta_x

def right_riem_sum(delta_x,a, b, n):
    sum = 0
    i = 1
    while i <= n:
        x_i = a + i * delta_x
        sum += f(x_i)
        i += 1
    return sum * delta_x

def midpoint_method(delta_x,a, b, n):
    sum = 0
    i = 0
    while i < n:
        x_midpoint = a + (i + 0.5) * delta_x
        sum += f(x_midpoint)
        i += 1
    return sum * delta_x

def trapezoidal_method(delta_x,a, b, n):
    sum = 0
    i=0
    while i < n:
        x_i = a + i*delta_x
        x_next = a + (i + 1)*delta_x
        sum += 0.5 * (f(x_i) + f(x_next))
        i+=1
    return sum * delta_x

a = 0
b = 4

actual_integral = (1/3) * (b**3 - a**3)

delta_x_values = np.linspace(1e-4,1.0,100)

left_sums = []
right_sums = []
midpoint_sums = []
trapezoidal_sums = []

for delta_x in delta_x_values:
    n = int((b - a) / delta_x)

    left_sum = left_riem_sum(delta_x, a, b, n)
    right_sum = right_riem_sum(delta_x,a, b, n)
    midpoint_sum = midpoint_method(delta_x,a, b, n)
    trapezoidal_sum = trapezoidal_method(delta_x,a, b, n)

    left_sums.append(left_sum)
    right_sums.append(right_sum)
    midpoint_sums.append(midpoint_sum)
    trapezoidal_sums.append(trapezoidal_sum)

    print(f"Δx = {delta_x}:")
    print(f"Left Riemann Sum: {left_sum}")
    print(f"Right Riemann Sum: {right_sum}")
    print(f"Midpoint Method: {midpoint_sum}")
    print(f"Trapezoidal Method: {trapezoidal_sum}")
    print(f"Actual Integral: {actual_integral}\n")

plt.figure(figsize=(10, 6))
plt.plot(delta_x_values, left_sums, label='Left Riemann Sum', marker='o')
plt.plot(delta_x_values, right_sums, label='Right Riemann Sum', marker='o')
plt.plot(delta_x_values, midpoint_sums, label='Midpoint Method', marker='o')
plt.plot(delta_x_values, trapezoidal_sums, label='Trapezoidal Method', marker='o')
plt.axhline(actual_integral, color='r', linestyle='--', label='Actual Integral')
plt.xlabel('Δx')
plt.ylabel('Approximations')
plt.title('Approximations of Integral vs. Δx')
plt.legend()
plt.show()
# Out:
# Δx = 0.0001:
# Left Riemann Sum: 21.332533340000122
# Right Riemann Sum: 21.334133340000122
# Midpoint Method: 21.333333329999974
# Trapezoidal Method: 21.333333339999953
# Actual Integral: 21.333333333333332
#
# Δx = 0.010199999999999999:
# Left Riemann Sum: 21.226278171167994
# Right Riemann Sum: 21.389347637279993
# Midpoint Method: 21.307708905839995
# Trapezoidal Method: 21.30781290422399
# Actual Integral: 21.333333333333332
#
# Δx = 0.0203:
# Left Riemann Sum: 21.156884309722003
# Right Riemann Sum: 21.481538166165002
# Midpoint Method: 21.318799240663743
# Trapezoidal Method: 21.31921123794349
# Actual Integral: 21.333333333333332
#
# Δx = 0.0304:
# Left Riemann Sum: 20.812519403520003
# Right Riemann Sum: 21.294648500224003
# Midpoint Method: 21.052663858176
# Trapezoidal Method: 21.053583951872003
# Actual Integral: 21.333333333333332
#
# Δx = 0.0405:
# Left Riemann Sum: 20.523254968124995
# Right Riemann Sum: 21.161249888624994
# Midpoint Method: 20.840624890312498
# Trapezoidal Method: 20.842252428375005
# Actual Integral: 21.333333333333332
#
# Δx = 0.0506:
# Left Riemann Sum: 20.889192233624
# Right Riemann Sum: 21.69774009568
# Midpoint Method: 21.290907468885997
# Trapezoidal Method: 21.293466164652
# Actual Integral: 21.333333333333332
#
# Δx = 0.060700000000000004:
# Left Riemann Sum: 20.003125685920004
# Right Riemann Sum: 20.948040780095003
# Midpoint Method: 20.471948944183755
# Trapezoidal Method: 20.475583233007498
# Actual Integral: 21.333333333333332
#
# Δx = 0.0708:
# Left Riemann Sum: 20.221912085760003
# Right Riemann Sum: 21.334862529792005
# Midpoint Method: 20.773418779007997
# Trapezoidal Method: 20.778387307776004
# Actual Integral: 21.333333333333332
#
# Δx = 0.0809:
# Left Riemann Sum: 20.132762305095998
# Right Riemann Sum: 21.404032089825
# Midpoint Method: 20.761911127130247
# Trapezoidal Method: 20.768397197460494
# Actual Integral: 21.333333333333332
#
# Δx = 0.091:
# Left Riemann Sum: 19.280114035
# Right Riemann Sum: 20.673466814
# Midpoint Method: 19.968689536250004
# Trapezoidal Method: 19.976790424499995
# Actual Integral: 21.333333333333332
#
# Δx = 0.1011:
# Left Riemann Sum: 19.653556211289
# Right Riemann Sum: 21.22530335874
# Midpoint Method: 20.42935448278725
# Trapezoidal Method: 20.439429785014497
# Actual Integral: 21.333333333333332
#
# Δx = 0.1112:
# Left Riemann Sum: 18.817380359679998
# Right Riemann Sum: 20.501800596479995
# Midpoint Method: 19.647558904959997
# Trapezoidal Method: 19.65959047808
# Actual Integral: 21.333333333333332
#
# Δx = 0.1213:
# Left Riemann Sum: 18.590170538351998
# Right Riemann Sum: 20.41777562968
# Midpoint Method: 19.489694919240005
# Trapezoidal Method: 19.503973084016007
# Actual Integral: 21.333333333333332
#
# Δx = 0.1314:
# Left Riemann Sum: 19.40913181691999
# Right Riemann Sum: 21.451004246519993
# Midpoint Method: 20.413052428139995
# Trapezoidal Method: 20.430068031719994
# Actual Integral: 21.333333333333332
#
# Δx = 0.1415:
# Left Riemann Sum: 19.633718238749992
# Right Riemann Sum: 21.854906564749992
# Midpoint Method: 20.724480363124997
# Trapezoidal Method: 20.744312401749994
# Actual Integral: 21.333333333333332
#
# Δx = 0.15159999999999998:
# Left Riemann Sum: 19.249962430399997
# Right Riemann Sum: 21.605251951295994
# Midpoint Method: 20.404960176223994
# Trapezoidal Method: 20.427607190847993
# Actual Integral: 21.333333333333332
#
# Δx = 0.16169999999999998:
# Left Riemann Sum: 18.281664936611996
# Right Riemann Sum: 20.716965353699994
# Midpoint Method: 19.473947432477992
# Trapezoidal Method: 19.49931514515599
# Actual Integral: 21.333333333333332
#
# Δx = 0.17179999999999998:
# Left Riemann Sum: 19.243375690439994
# Right Riemann Sum: 21.925785635167994
# Midpoint Method: 20.55542403296999
# Trapezoidal Method: 20.584580662803994
# Actual Integral: 21.333333333333332
#
# Δx = 0.18189999999999998:
# Left Riemann Sum: 17.273486063329994
# Right Riemann Sum: 19.927704653548997
# Midpoint Method: 18.56899751807974
# Trapezoidal Method: 18.600595358439488
# Actual Integral: 21.333333333333332
#
# Δx = 0.19199999999999998:
# Left Riemann Sum: 17.482383359999993
# Right Riemann Sum: 20.31353855999999
# Midpoint Method: 18.862571519999992
# Trapezoidal Method: 18.897960959999995
# Actual Integral: 21.333333333333332
#
# Δx = 0.20209999999999997:
# Left Riemann Sum: 17.409067945448996
# Right Riemann Sum: 20.388998494669995
# Midpoint Method: 18.85982360756974
# Trapezoidal Method: 18.899033220059493
# Actual Integral: 21.333333333333332
#
# Δx = 0.21219999999999997:
# Left Riemann Sum: 17.055888928679995
# Right Riemann Sum: 20.15174775943199
# Midpoint Method: 18.560820304739995
# Trapezoidal Method: 18.60381834405599
# Actual Integral: 21.333333333333332
#
# Δx = 0.22229999999999997:
# Left Riemann Sum: 16.434253496231992
# Right Riemann Sum: 19.60905246709499
# Midpoint Method: 17.974964761503742
# Trapezoidal Method: 18.021652981663497
# Actual Integral: 21.333333333333332
#
# Δx = 0.23239999999999997:
# Left Riemann Sum: 18.777594863103992
# Right Riemann Sum: 22.40508477983999
# Midpoint Method: 20.537994381519994
# Trapezoidal Method: 20.59133982147199
# Actual Integral: 21.333333333333332
#
# Δx = 0.2425:
# Left Riemann Sum: 17.683039374999996
# Right Riemann Sum: 21.333731375
# Midpoint Method: 19.4513433125
# Trapezoidal Method: 19.508385375
# Actual Integral: 21.333333333333332
#
# Δx = 0.2526:
# Left Riemann Sum: 16.359351389639997
# Right Riemann Sum: 19.985808594239998
# Midpoint Method: 18.112139038529996
# Trapezoidal Method: 18.172579991939998
# Actual Integral: 21.333333333333332
#
# Δx = 0.2627:
# Left Riemann Sum: 18.401204871245
# Right Riemann Sum: 22.48028969492
# Midpoint Method: 20.37276253602125
# Trapezoidal Method: 20.440747283082494
# Actual Integral: 21.333333333333332
#
# Δx = 0.2728:
# Left Riemann Sum: 16.627118796288
# Right Riemann Sum: 20.606258337279996
# Midpoint Method: 18.545632503551996
# Trapezoidal Method: 18.616688566784003
# Actual Integral: 21.333333333333332
#
# Δx = 0.2829:
# Left Riemann Sum: 18.543117238190995
# Right Riemann Sum: 22.980786320834994
# Midpoint Method: 20.682707688751496
# Trapezoidal Method: 20.761951779512994
# Actual Integral: 21.333333333333332
#
# Δx = 0.293:
# Left Riemann Sum: 16.34994205
# Right Riemann Sum: 20.600926982999997
# Midpoint Method: 18.393684806249997
# Trapezoidal Method: 18.4754345165
# Actual Integral: 21.333333333333332
#
# Δx = 0.3031:
# Left Riemann Sum: 18.099691214149995
# Right Riemann Sum: 22.805610929828998
# Midpoint Method: 20.36215261591875
# Trapezoidal Method: 20.452651071989497
# Actual Integral: 21.333333333333332
#
# Δx = 0.3132:
# Left Riemann Sum: 15.545896679807996
# Right Riemann Sum: 19.970025379199996
# Midpoint Method: 17.665791681599995
# Trapezoidal Method: 17.757961029504
# Actual Integral: 21.333333333333332
#
# Δx = 0.3233:
# Left Riemann Sum: 17.098878670521994
# Right Riemann Sum: 21.964962719049996
# Midpoint Method: 19.430543943774996
# Trapezoidal Method: 19.531920694785995
# Actual Integral: 21.333333333333332
#
# Δx = 0.3334:
# Left Riemann Sum: 14.267816526039997
# Right Riemann Sum: 18.751987434223995
# Midpoint Method: 16.407989004945996
# Trapezoidal Method: 16.509901980131993
# Actual Integral: 21.333333333333332
#
# Δx = 0.34349999999999997:
# Left Riemann Sum: 15.604180081874997
# Right Riemann Sum: 20.508350964749997
# Midpoint Method: 17.944807094156246
# Trapezoidal Method: 18.056265523312494
# Actual Integral: 21.333333333333332
#
# Δx = 0.35359999999999997:
# Left Riemann Sum: 17.021487042559997
# Right Riemann Sum: 22.371097255935997
# Midpoint Method: 19.574710098943996
# Trapezoidal Method: 19.696292149247995
# Actual Integral: 21.333333333333332
#
# Δx = 0.36369999999999997:
# Left Riemann Sum: 13.711177818104995
# Right Riemann Sum: 18.52211740340499
# Midpoint Method: 15.996374121122498
# Trapezoidal Method: 16.116647610754995
# Actual Integral: 21.333333333333332
#
# Δx = 0.37379999999999997:
# Left Riemann Sum: 14.885476832519995
# Right Riemann Sum: 20.108451159719994
# Midpoint Method: 17.366389637939992
# Trapezoidal Method: 17.496963996119998
# Actual Integral: 21.333333333333332
#
# Δx = 0.38389999999999996:
# Left Riemann Sum: 16.124980434914995
# Right Riemann Sum: 21.782868306814994
# Midpoint Method: 18.812477174067492
# Trapezoidal Method: 18.953924370864993
# Actual Integral: 21.333333333333332
#
# Δx = 0.39399999999999996:
# Left Riemann Sum: 17.431450439999992
# Right Riemann Sum: 23.54774883999999
# Midpoint Method: 20.336692179999993
# Trapezoidal Method: 20.489599639999994
# Actual Integral: 21.333333333333332
#
# Δx = 0.40409999999999996:
# Left Riemann Sum: 13.461601147883997
# Right Riemann Sum: 18.806648662484996
# Midpoint Method: 15.985651363112247
# Trapezoidal Method: 16.134124905184493
# Actual Integral: 21.333333333333332
#
# Δx = 0.41419999999999996:
# Left Riemann Sum: 14.496409582751996
# Right Riemann Sum: 20.252336917079997
# Midpoint Method: 17.214486379517997
# Trapezoidal Method: 17.374373249915994
# Actual Integral: 21.333333333333332
#
# Δx = 0.42429999999999995:
# Left Riemann Sum: 15.582935129027993
# Right Riemann Sum: 21.77027701849499
# Midpoint Method: 18.504735465720746
# Trapezoidal Method: 18.676606073761494
# Actual Integral: 21.333333333333332
#
# Δx = 0.43439999999999995:
# Left Riemann Sum: 16.722438875135996
# Right Riemann Sum: 23.362230781439994
# Midpoint Method: 19.857896164223995
# Trapezoidal Method: 20.042334828287995
# Actual Integral: 21.333333333333332
#
# Δx = 0.44449999999999995:
# Left Riemann Sum: 12.295418957499995
# Right Riemann Sum: 17.916181909499993
# Midpoint Method: 14.930151591249995
# Trapezoidal Method: 15.105800433499995
# Actual Integral: 21.333333333333332
#
# Δx = 0.45459999999999995:
# Left Riemann Sum: 13.152742867039995
# Right Riemann Sum: 19.165425320543992
# Midpoint Method: 15.971187767119995
# Trapezoidal Method: 16.159084093791993
# Actual Integral: 21.333333333333332
#
# Δx = 0.46469999999999995:
# Left Riemann Sum: 14.049020723219996
# Right Riemann Sum: 20.471430196691994
# Midpoint Method: 17.059525163909992
# Trapezoidal Method: 17.260225459955993
# Actual Integral: 21.333333333333332
#
# Δx = 0.47479999999999994:
# Left Riemann Sum: 14.985117978879995
# Right Riemann Sum: 21.83545762636799
# Midpoint Method: 18.196214688639994
# Trapezoidal Method: 18.410287802623994
# Actual Integral: 21.333333333333332
#
# Δx = 0.4849:
# Left Riemann Sum: 15.961900086859998
# Right Riemann Sum: 23.258768697995997
# Midpoint Method: 19.38230724833
# Trapezoidal Method: 19.610334392427998
# Actual Integral: 21.333333333333332
#
# Δx = 0.495:
# Left Riemann Sum: 16.9802325
# Right Riemann Sum: 24.7426245
# Midpoint Method: 20.61885375
# Trapezoidal Method: 20.861428499999995
# Actual Integral: 21.333333333333332
#
# Δx = 0.5051:
# Left Riemann Sum: 11.726637436241
# Right Riemann Sum: 18.040980671139998
# Midpoint Method: 14.658296795301249
# Trapezoidal Method: 14.8838090536905
# Actual Integral: 21.333333333333332
#
# Δx = 0.5152:
# Left Riemann Sum: 12.444256534528
# Right Riemann Sum: 19.14501005312
# Midpoint Method: 15.55532066816
# Trapezoidal Method: 15.794633293824
# Actual Integral: 21.333333333333332
#
# Δx = 0.5253:
# Left Riemann Sum: 13.190570964206998
# Right Riemann Sum: 20.293186098779998
# Midpoint Method: 16.488213705258747
# Trapezoidal Method: 16.741878531493498
# Actual Integral: 21.333333333333332
#
# Δx = 0.5354:
# Left Riemann Sum: 13.966143269623997
# Right Riemann Sum: 21.486374260959998
# Midpoint Method: 17.457679087029998
# Trapezoidal Method: 17.726258765292
# Actual Integral: 21.333333333333332
#
# Δx = 0.5455:
# Left Riemann Sum: 14.771535995124996
# Right Riemann Sum: 22.725439992499997
# Midpoint Method: 18.46441999390625
# Trapezoidal Method: 18.7484879938125
# Actual Integral: 21.333333333333332
#
# Δx = 0.5556:
# Left Riemann Sum: 15.607311685055999
# Right Riemann Sum: 24.011248746239996
# Midpoint Method: 19.50913960632
# Trapezoidal Method: 19.809280215647995
# Actual Integral: 21.333333333333332
#
# Δx = 0.5657:
# Left Riemann Sum: 16.474032883762998
# Right Riemann Sum: 25.344665975019996
# Midpoint Method: 20.592541104703745
# Trapezoidal Method: 20.909349429391494
# Actual Integral: 21.333333333333332
#
# Δx = 0.5758:
# Left Riemann Sum: 10.499718873159999
# Right Riemann Sum: 17.372262135591996
# Midpoint Method: 13.649634535107998
# Trapezoidal Method: 13.935990504375999
# Actual Integral: 21.333333333333332
#
# Δx = 0.5859:
# Left Riemann Sum: 11.061988012845
# Right Riemann Sum: 18.302561984888996
# Midpoint Method: 14.380584416698499
# Trapezoidal Method: 14.682274998866998
# Actual Integral: 21.333333333333332
#
# Δx = 0.596:
# Left Riemann Sum: 11.643980479999998
# Right Riemann Sum: 19.265494975999992
# Midpoint Method: 15.137174623999998
# Trapezoidal Method: 15.454737727999998
# Actual Integral: 21.333333333333332
#
# Δx = 0.6061:
# Left Riemann Sum: 12.246036273955
# Right Riemann Sum: 20.261623653271
# Midpoint Method: 15.919847156141497
# Trapezoidal Method: 16.253829963612997
# Actual Integral: 21.333333333333332
#
# Δx = 0.6162:
# Left Riemann Sum: 12.868495394039998
# Right Riemann Sum: 21.291510561048
# Midpoint Method: 16.729044012251997
# Trapezoidal Method: 17.080002977543998
# Actual Integral: 21.333333333333332
#
# Δx = 0.6263:
# Left Riemann Sum: 13.511697839584999
# Right Riemann Sum: 22.355718243676996
# Midpoint Method: 17.565207191460498
# Trapezoidal Method: 17.933708041630997
# Actual Integral: 21.333333333333332
#
# Δx = 0.6364:
# Left Riemann Sum: 14.175983609919998
# Right Riemann Sum: 23.45480924550399
# Midpoint Method: 18.428778692895996
# Trapezoidal Method: 18.815396427711995
# Actual Integral: 21.333333333333332
#
# Δx = 0.6465:
# Left Riemann Sum: 14.861692704374999
# Right Riemann Sum: 24.589346110874995
# Midpoint Method: 19.320200515687496
# Trapezoidal Method: 19.725519407624997
# Actual Integral: 21.333333333333332
#
# Δx = 0.6566:
# Left Riemann Sum: 15.569165122279998
# Right Riemann Sum: 25.759891384135994
# Midpoint Method: 20.239914658963997
# Trapezoidal Method: 20.664528253207997
# Actual Integral: 21.333333333333332
#
# Δx = 0.6667:
# Left Riemann Sum: 8.89022228889
# Right Riemann Sum: 16.298740862964998
# Midpoint Method: 12.224055647223748
# Trapezoidal Method: 12.594481575927498
# Actual Integral: 21.333333333333332
#
# Δx = 0.6768:
# Left Riemann Sum: 9.300414504959999
# Right Riemann Sum: 17.050759925759998
# Midpoint Method: 12.788069944319998
# Trapezoidal Method: 13.175587215359997
# Actual Integral: 21.333333333333332
#
# Δx = 0.6869:
# Left Riemann Sum: 9.723033987269998
# Right Riemann Sum: 17.825562309994996
# Midpoint Method: 13.369171732496248
# Trapezoidal Method: 13.774298148632498
# Actual Integral: 21.333333333333332
#
# Δx = 0.697:
# Left Riemann Sum: 10.158266189999999
# Right Riemann Sum: 18.623488014999996
# Midpoint Method: 13.967616011249996
# Trapezoidal Method: 14.390877102499998
# Actual Integral: 21.333333333333332
#
# Δx = 0.7071:
# Left Riemann Sum: 10.606296567329998
# Right Riemann Sum: 19.444877040105
# Midpoint Method: 14.583657780078747
# Trapezoidal Method: 15.025586803717497
# Actual Integral: 21.333333333333332
#
# Δx = 0.7172:
# Left Riemann Sum: 11.067310573439999
# Right Riemann Sum: 20.29006938464
# Midpoint Method: 15.217552038479997
# Trapezoidal Method: 15.678689979039996
# Actual Integral: 21.333333333333332
#
# Δx = 0.7273:
# Left Riemann Sum: 11.541493662509996
# Right Riemann Sum: 21.159405047934996
# Midpoint Method: 15.869553785951245
# Trapezoidal Method: 16.350449355222494
# Actual Integral: 21.333333333333332
#
# Δx = 0.7373999999999999:
# Left Riemann Sum: 12.029031288719995
# Right Riemann Sum: 22.053224029319995
# Midpoint Method: 16.539918021989997
# Trapezoidal Method: 17.041127659019995
# Actual Integral: 21.333333333333332
#
# Δx = 0.7474999999999999:
# Left Riemann Sum: 12.530108906249998
# Right Riemann Sum: 22.971866328124996
# Midpoint Method: 17.228899746093745
# Trapezoidal Method: 17.750987617187494
# Actual Integral: 21.333333333333332
#
# Δx = 0.7575999999999999:
# Left Riemann Sum: 13.044911969279998
# Right Riemann Sum: 23.915671943679992
# Midpoint Method: 17.936753957759997
# Trapezoidal Method: 18.48029195647999
# Actual Integral: 21.333333333333332
#
# Δx = 0.7676999999999999:
# Left Riemann Sum: 13.573625931989996
# Right Riemann Sum: 24.884980875314994
# Midpoint Method: 18.663735656486242
# Trapezoidal Method: 19.229303403652494
# Actual Integral: 21.333333333333332
#
# Δx = 0.7777999999999999:
# Left Riemann Sum: 14.116436248559994
# Right Riemann Sum: 25.880133122359993
# Midpoint Method: 19.410099841769995
# Trapezoidal Method: 19.998284685459996
# Actual Integral: 21.333333333333332
#
# Δx = 0.7878999999999999:
# Left Riemann Sum: 14.673528373169997
# Right Riemann Sum: 26.901468684144998
# Midpoint Method: 20.176101513108744
# Trapezoidal Method: 20.787498528657494
# Actual Integral: 21.333333333333332
#
# Δx = 0.7979999999999999:
# Left Riemann Sum: 15.245087759999995
# Right Riemann Sum: 27.949327559999993
# Midpoint Method: 20.961995669999997
# Trapezoidal Method: 21.597207659999995
# Actual Integral: 21.333333333333332
#
# Δx = 0.8080999999999999:
# Left Riemann Sum: 7.387939936173998
# Right Riemann Sum: 15.831299863229995
# Midpoint Method: 11.081909904260998
# Trapezoidal Method: 11.609619899701999
# Actual Integral: 21.333333333333332
#
# Δx = 0.8181999999999999:
# Left Riemann Sum: 7.6684300639519964
# Right Riemann Sum: 16.432350137039993
# Midpoint Method: 11.502645095927996
# Trapezoidal Method: 12.050390100495997
# Actual Integral: 21.333333333333332
#
# Δx = 0.8282999999999999:
# Left Riemann Sum: 7.955931216617996
# Right Riemann Sum: 17.04842403560999
# Midpoint Method: 11.933896824926997
# Trapezoidal Method: 12.502177626113996
# Actual Integral: 21.333333333333332
#
# Δx = 0.8383999999999999:
# Left Riemann Sum: 8.250529939455998
# Right Riemann Sum: 17.679707013119994
# Midpoint Method: 12.375794909183996
# Trapezoidal Method: 12.965118476287996
# Actual Integral: 21.333333333333332
#
# Δx = 0.8484999999999999:
# Left Riemann Sum: 8.552312777749998
# Right Riemann Sum: 18.326384523749994
# Midpoint Method: 12.828469166624997
# Trapezoidal Method: 13.439348650749995
# Actual Integral: 21.333333333333332
#
# Δx = 0.8585999999999999:
# Left Riemann Sum: 8.861366276783997
# Right Riemann Sum: 18.988642021679993
# Midpoint Method: 13.292049415175994
# Trapezoidal Method: 13.925004149231995
# Actual Integral: 21.333333333333332
#
# Δx = 0.8686999999999999:
# Left Riemann Sum: 9.177776981841996
# Right Riemann Sum: 19.666664961089992
# Midpoint Method: 13.766665472762996
# Trapezoidal Method: 14.422220971465997
# Actual Integral: 21.333333333333332
#
# Δx = 0.8787999999999999:
# Left Riemann Sum: 9.501631438207996
# Right Riemann Sum: 20.360638796159996
# Midpoint Method: 14.252447157311996
# Trapezoidal Method: 14.931135117183997
# Actual Integral: 21.333333333333332
#
# Δx = 0.8888999999999999:
# Left Riemann Sum: 9.833016191165997
# Right Riemann Sum: 21.070748981069993
# Midpoint Method: 14.749524286748997
# Trapezoidal Method: 15.451882586117994
# Actual Integral: 21.333333333333332
#
# Δx = 0.8989999999999999:
# Left Riemann Sum: 10.172017785999998
# Right Riemann Sum: 21.797180969999996
# Midpoint Method: 15.258026678999993
# Trapezoidal Method: 15.984599377999993
# Actual Integral: 21.333333333333332
#
# Δx = 0.9090999999999999:
# Left Riemann Sum: 10.518722767993998
# Right Riemann Sum: 22.540120217129992
# Midpoint Method: 15.778084151990996
# Trapezoidal Method: 16.529421492561994
# Actual Integral: 21.333333333333332
#
# Δx = 0.9191999999999999:
# Left Riemann Sum: 10.873217682431996
# Right Riemann Sum: 23.29975217663999
# Midpoint Method: 16.309826523647995
# Trapezoidal Method: 17.086484929535995
# Actual Integral: 21.333333333333332
#
# Δx = 0.9292999999999999:
# Left Riemann Sum: 11.235589074597994
# Right Riemann Sum: 24.07626230270999
# Midpoint Method: 16.853383611896998
# Trapezoidal Method: 17.65592568865399
# Actual Integral: 21.333333333333332
#
# Δx = 0.9393999999999999:
# Left Riemann Sum: 11.605923489775996
# Right Riemann Sum: 24.869836049519993
# Midpoint Method: 17.408885234663995
# Trapezoidal Method: 18.237879769647996
# Actual Integral: 21.333333333333332
#
# Δx = 0.9494999999999999:
# Left Riemann Sum: 11.984307473249995
# Right Riemann Sum: 25.68065887124999
# Midpoint Method: 17.976461209874994
# Trapezoidal Method: 18.83248317224999
# Actual Integral: 21.333333333333332
#
# Δx = 0.9595999999999999:
# Left Riemann Sum: 12.370827570303996
# Right Riemann Sum: 26.508916222079993
# Midpoint Method: 18.55624135545599
# Trapezoidal Method: 19.439871896191992
# Actual Integral: 21.333333333333332
#
# Δx = 0.9697:
# Left Riemann Sum: 12.765570326222003
# Right Riemann Sum: 27.35479355619
# Midpoint Method: 19.148355489333003
# Trapezoidal Method: 20.060181941206
# Actual Integral: 21.333333333333332
#
# Δx = 0.9798:
# Left Riemann Sum: 13.168622286287999
# Right Riemann Sum: 28.21847632776
# Midpoint Method: 19.752933429432
# Trapezoidal Method: 20.693549307024004
# Actual Integral: 21.333333333333332
#
# Δx = 0.9899:
# Left Riemann Sum: 13.580069995786
# Right Riemann Sum: 29.10014999097
# Midpoint Method: 20.370104993679
# Trapezoidal Method: 21.340109993378
# Actual Integral: 21.333333333333332
#
# Δx = 1.0:
# Left Riemann Sum: 14.0
# Right Riemann Sum: 30.0
# Midpoint Method: 21.0
# Trapezoidal Method: 22.0
# Actual Integral: 21.333333333333332
