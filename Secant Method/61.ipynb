# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**3 - x - 1

def secant_method(x0, x1, tol=1e-6, max_iter=100):
    approximation_errors = []
    relative_approximation_errors = []
    x_values = []
    i = 0

    while i < max_iter:
        xi_minus_1 = x0
        fi_minus_1 = f(xi_minus_1)

        xi = x1
        fi = f(xi)

        if xi == xi_minus_1:
            print("xi and xi_minus_1 are the same. Secant method may not converge.")
            return None

        f_prime_i = (fi - fi_minus_1) / (xi - xi_minus_1)

        xi_plus_1 = xi - fi / f_prime_i
        approx_error = abs(xi_plus_1 - xi)
        rel_approx_error = abs(approx_error / xi_plus_1)

        print(f"Iteration {i+1}:")
        print(f"xi-1 = {xi_minus_1:.6f}, f(xi-1) = {fi_minus_1:.6f}")
        print(f"xi = {xi:.6f}, f(xi) = {fi:.6f}, f'(xi) = {f_prime_i:.6f}")
        print(f"xi+1 = {xi_plus_1:.6f}, Approximation error = {approx_error:.6f}, Relative approximation error = {rel_approx_error:.6f}")

        x_values.append(xi_plus_1)
        approximation_errors.append(approx_error)
        relative_approximation_errors.append(rel_approx_error)

        if approx_error < tol:
            print("Converged successfully!")
            break

        x0 = xi
        x1 = xi_plus_1
        i += 1

    return x_values, approximation_errors, relative_approximation_errors

x0_secant = 50
x1_secant = 48

x_values_secant, approximation_errors_secant, relative_approximation_errors_secant = secant_method(x0_secant, x1_secant)

# Visualizing the approximation errors using a bar chart
iterations_secant = list(range(1, len(approximation_errors_secant) + 1))
plt.bar(iterations_secant, approximation_errors_secant)
plt.xlabel('Iteration Number')
plt.ylabel('Approximation Error')
plt.title('Approximation Errors using Secant Method')
plt.show()

# Visualizing the relative approximation errors using a bar chart
plt.bar(iterations_secant, relative_approximation_errors_secant)
plt.xlabel('Iteration Number')
plt.ylabel('Relative Approximation Error')
plt.title('Relative Approximation Errors using Secant Method')
plt.show()
# Out:
# Iteration 1:
# xi-1 = 50.000000, f(xi-1) = 124949.000000
# xi = 48.000000, f(xi) = 110543.000000, f'(xi) = 7203.000000
# xi+1 = 32.653200, Approximation error = 15.346800, Relative approximation error = 0.469994
# Iteration 2:
# xi-1 = 48.000000, f(xi-1) = 110543.000000
# xi = 32.653200, f(xi) = 34782.216422, f'(xi) = 4936.585077
# xi+1 = 25.607395, Approximation error = 7.045805, Relative approximation error = 0.275147
# Iteration 3:
# xi-1 = 32.653200, f(xi-1) = 34782.216422
# xi = 25.607395, f(xi) = 16765.151835, f'(xi) = 2557.133539
# xi+1 = 19.051166, Approximation error = 6.556229, Relative approximation error = 0.344138
# Iteration 4:
# xi-1 = 25.607395, f(xi-1) = 16765.151835
# xi = 19.051166, f(xi) = 6894.511419, f'(xi) = 1505.536359
# xi+1 = 14.471728, Approximation error = 4.579439, Relative approximation error = 0.316440
# Iteration 5:
# xi-1 = 19.051166, f(xi-1) = 6894.511419
# xi = 14.471728, f(xi) = 3015.355296, f'(xi) = 847.081139
# xi+1 = 10.912027, Approximation error = 3.559701, Relative approximation error = 0.326218
# Iteration 6:
# xi-1 = 14.471728, f(xi-1) = 3015.355296
# xi = 10.912027, f(xi) = 1287.408517, f'(xi) = 485.419124
# xi+1 = 8.259868, Approximation error = 2.652159, Relative approximation error = 0.321090
# Iteration 7:
# xi-1 = 10.912027, f(xi-1) = 1287.408517
# xi = 8.259868, f(xi) = 554.273183, f'(xi) = 276.429670
# xi+1 = 6.254754, Approximation error = 2.005115, Relative approximation error = 0.320575
# Iteration 8:
# xi-1 = 8.259868, f(xi-1) = 554.273183
# xi = 6.254754, f(xi) = 237.443381, f'(xi) = 158.010816
# xi+1 = 4.752050, Approximation error = 1.502703, Relative approximation error = 0.316222
# Iteration 9:
# xi-1 = 6.254754, f(xi-1) = 237.443381
# xi = 4.752050, f(xi) = 101.558675, f'(xi) = 90.426834
# xi+1 = 3.628947, Approximation error = 1.123103, Relative approximation error = 0.309485
# Iteration 10:
# xi-1 = 4.752050, f(xi-1) = 101.558675
# xi = 3.628947, f(xi) = 43.161593, f'(xi) = 51.996181
# xi+1 = 2.798856, Approximation error = 0.830092, Relative approximation error = 0.296583
# Iteration 11:
# xi-1 = 3.628947, f(xi-1) = 43.161593
# xi = 2.798856, f(xi) = 18.126239, f'(xi) = 30.159749
# xi+1 = 2.197848, Approximation error = 0.601008, Relative approximation error = 0.273453
# Iteration 12:
# xi-1 = 2.798856, f(xi-1) = 18.126239
# xi = 2.197848, f(xi) = 7.418935, f'(xi) = 17.815587
# xi+1 = 1.781419, Approximation error = 0.416429, Relative approximation error = 0.233763
# Iteration 13:
# xi-1 = 2.197848, f(xi-1) = 7.418935
# xi = 1.781419, f(xi) = 2.871828, f'(xi) = 10.919275
# xi+1 = 1.518413, Approximation error = 0.263005, Relative approximation error = 0.173211
# Iteration 14:
# xi-1 = 1.781419, f(xi-1) = 2.871828
# xi = 1.518413, f(xi) = 0.982408, f'(xi) = 7.183960
# xi+1 = 1.381663, Approximation error = 0.136750, Relative approximation error = 0.098975
# Iteration 15:
# xi-1 = 1.518413, f(xi-1) = 0.982408
# xi = 1.381663, f(xi) = 0.255922, f'(xi) = 5.312507
# xi+1 = 1.333490, Approximation error = 0.048173, Relative approximation error = 0.036126
# Iteration 16:
# xi-1 = 1.381663, f(xi-1) = 0.255922
# xi = 1.333490, f(xi) = 0.037714, f'(xi) = 4.529620
# xi+1 = 1.325163, Approximation error = 0.008326, Relative approximation error = 0.006283
# Iteration 17:
# xi-1 = 1.333490, f(xi-1) = 0.037714
# xi = 1.325163, f(xi) = 0.001901, f'(xi) = 4.301344
# xi+1 = 1.324722, Approximation error = 0.000442, Relative approximation error = 0.000334
# Iteration 18:
# xi-1 = 1.325163, f(xi-1) = 0.001901
# xi = 1.324722, f(xi) = 0.000015, f'(xi) = 4.266418
# xi+1 = 1.324718, Approximation error = 0.000004, Relative approximation error = 0.000003
# Iteration 19:
# xi-1 = 1.324722, f(xi-1) = 0.000015
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264647
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Converged successfully!

# %%
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return x**3 - x - 1

def f_of(x):
    return 3 * x**2 - 1

def newton_raphson_method(x0, max=20):
    approx_error = []
    relative_approximation_errors = []
    x_values = []
    i = 0

    while i < max:
        xi = x0
        fi = f(xi)
        f_of_i = f_of(xi)

        xi_plus_1 = xi - fi / f_of_i
        error = abs(xi_plus_1 - xi)
        rel_approxerror = abs(error / xi_plus_1)

        print(f"Iteration {i+1}:")
        print(f"xi = {xi:.6f}, f(xi) = {fi:.6f}, f'(xi) = {f_of_i:.6f}")
        print(f"xi+1 = {xi_plus_1:.6f}, Approximation error = {error:.6f}, Relative approximation error = {rel_approxerror:.6f}")

        x_values.append(xi_plus_1)
        approx_error.append(error)

        x_values.append(xi_plus_1 )
        relative_approximation_errors.append(rel_approxerror)

        x0 = xi_plus_1
        i += 1

    return x_values, approx_error, relative_approximation_errors

def secant_method(x0, x1, max_iter=20):
    approximation_errors = []
    relative_approximation_errors = []
    x_values = []
    i = 0

    while i < max_iter:
        xi_minus_1 = x0
        fi_minus_1 = f(xi_minus_1)

        xi = x1
        fi = f(xi)


        f_prime_i = (fi - fi_minus_1) / (xi - xi_minus_1)

        xi_plus_1 = xi - fi / f_prime_i
        approx_error = abs(xi_plus_1 - xi)
        rel_approx_error = abs(approx_error / xi_plus_1)

        print(f"Iteration {i+1}:")
        print(f"xi-1 = {xi_minus_1:.6f}, f(xi-1) = {fi_minus_1:.6f}")
        print(f"xi = {xi:.6f}, f(xi) = {fi:.6f}, f'(xi) = {f_prime_i:.6f}")
        print(f"xi+1 = {xi_plus_1:.6f}, Approximation error = {approx_error:.6f}, Relative approximation error = {rel_approx_error:.6f}")

        x_values.append(xi_plus_1)
        approximation_errors.append(approx_error)
        relative_approximation_errors.append(rel_approx_error)

        x0 = xi
        x1 = xi_plus_1
        i += 1

    return x_values, approximation_errors, relative_approximation_errors

x0_newton = 50
x0_secant = 50
x1_secant = 48

x_values_newton, approximation_errors_newton, rel_approx_error_newton = newton_raphson_method(x0_newton)

x_values_secant, approximation_errors_secant, rel_approx_error_secant = secant_method(x0_secant, x1_secant)


iterations_newton = list(range(1, len(approximation_errors_newton) + 1))
iterations_secant = list(range(1, len(approximation_errors_secant) + 1))

plt.plot(iterations_newton, approximation_errors_newton, label='Newton-Raphson')
plt.plot(iterations_secant, approximation_errors_secant, label='Secant')
plt.xlabel('Iteration Number')
plt.ylabel('Approximation Error')
plt.title('Approximation Errors: Newton-Raphson vs Secant Method')
plt.legend()
plt.show()

plt.plot(iterations_newton, rel_approx_error_newton, label='Newton-Raphson')
plt.plot(iterations_secant, rel_approx_error_secant, label='Secant')
plt.xlabel('Iteration Number')
plt.ylabel('Relative Approximation Error')
plt.title('Relative Approximation Errors: Newton-Raphson vs Secant Method')
plt.legend()
plt.show()
# Out:
# Iteration 1:
# xi = 50.000000, f(xi) = 124949.000000, f'(xi) = 7499.000000
# xi+1 = 33.337912, Approximation error = 16.662088, Relative approximation error = 0.499794
# Iteration 2:
# xi = 33.337912, f(xi) = 37017.962516, f'(xi) = 3333.249074
# xi+1 = 22.232242, Approximation error = 11.105669, Relative approximation error = 0.499530
# Iteration 3:
# xi = 22.232242, f(xi) = 10965.555822, f'(xi) = 1481.817785
# xi+1 = 14.832172, Approximation error = 7.400070, Relative approximation error = 0.498920
# Iteration 4:
# xi = 14.832172, f(xi) = 3247.146623, f'(xi) = 658.979971
# xi+1 = 9.904637, Approximation error = 4.927535, Relative approximation error = 0.497498
# Iteration 5:
# xi = 9.904637, f(xi) = 960.758503, f'(xi) = 293.305519
# xi+1 = 6.629014, Approximation error = 3.275624, Relative approximation error = 0.494134
# Iteration 6:
# xi = 6.629014, f(xi) = 283.675177, f'(xi) = 130.831464
# xi+1 = 4.460765, Approximation error = 2.168249, Relative approximation error = 0.486071
# Iteration 7:
# xi = 4.460765, f(xi) = 83.301414, f'(xi) = 58.695266
# xi+1 = 3.041546, Approximation error = 1.419219, Relative approximation error = 0.466611
# Iteration 8:
# xi = 3.041546, f(xi) = 24.095805, f'(xi) = 26.753008
# xi+1 = 2.140870, Approximation error = 0.900676, Relative approximation error = 0.420706
# Iteration 9:
# xi = 2.140870, f(xi) = 6.671427, f'(xi) = 12.749968
# xi+1 = 1.617619, Approximation error = 0.523250, Relative approximation error = 0.323470
# Iteration 10:
# xi = 1.617619, f(xi) = 1.615192, f'(xi) = 6.850075
# xi+1 = 1.381827, Approximation error = 0.235792, Relative approximation error = 0.170638
# Iteration 11:
# xi = 1.381827, f(xi) = 0.256699, f'(xi) = 4.728341
# xi+1 = 1.327538, Approximation error = 0.054289, Relative approximation error = 0.040895
# Iteration 12:
# xi = 1.327538, f(xi) = 0.012058, f'(xi) = 4.287071
# xi+1 = 1.324725, Approximation error = 0.002813, Relative approximation error = 0.002123
# Iteration 13:
# xi = 1.324725, f(xi) = 0.000031, f'(xi) = 4.264692
# xi+1 = 1.324718, Approximation error = 0.000007, Relative approximation error = 0.000006
# Iteration 14:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 15:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 16:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 17:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 18:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 19:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 20:
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 1:
# xi-1 = 50.000000, f(xi-1) = 124949.000000
# xi = 48.000000, f(xi) = 110543.000000, f'(xi) = 7203.000000
# xi+1 = 32.653200, Approximation error = 15.346800, Relative approximation error = 0.469994
# Iteration 2:
# xi-1 = 48.000000, f(xi-1) = 110543.000000
# xi = 32.653200, f(xi) = 34782.216422, f'(xi) = 4936.585077
# xi+1 = 25.607395, Approximation error = 7.045805, Relative approximation error = 0.275147
# Iteration 3:
# xi-1 = 32.653200, f(xi-1) = 34782.216422
# xi = 25.607395, f(xi) = 16765.151835, f'(xi) = 2557.133539
# xi+1 = 19.051166, Approximation error = 6.556229, Relative approximation error = 0.344138
# Iteration 4:
# xi-1 = 25.607395, f(xi-1) = 16765.151835
# xi = 19.051166, f(xi) = 6894.511419, f'(xi) = 1505.536359
# xi+1 = 14.471728, Approximation error = 4.579439, Relative approximation error = 0.316440
# Iteration 5:
# xi-1 = 19.051166, f(xi-1) = 6894.511419
# xi = 14.471728, f(xi) = 3015.355296, f'(xi) = 847.081139
# xi+1 = 10.912027, Approximation error = 3.559701, Relative approximation error = 0.326218
# Iteration 6:
# xi-1 = 14.471728, f(xi-1) = 3015.355296
# xi = 10.912027, f(xi) = 1287.408517, f'(xi) = 485.419124
# xi+1 = 8.259868, Approximation error = 2.652159, Relative approximation error = 0.321090
# Iteration 7:
# xi-1 = 10.912027, f(xi-1) = 1287.408517
# xi = 8.259868, f(xi) = 554.273183, f'(xi) = 276.429670
# xi+1 = 6.254754, Approximation error = 2.005115, Relative approximation error = 0.320575
# Iteration 8:
# xi-1 = 8.259868, f(xi-1) = 554.273183
# xi = 6.254754, f(xi) = 237.443381, f'(xi) = 158.010816
# xi+1 = 4.752050, Approximation error = 1.502703, Relative approximation error = 0.316222
# Iteration 9:
# xi-1 = 6.254754, f(xi-1) = 237.443381
# xi = 4.752050, f(xi) = 101.558675, f'(xi) = 90.426834
# xi+1 = 3.628947, Approximation error = 1.123103, Relative approximation error = 0.309485
# Iteration 10:
# xi-1 = 4.752050, f(xi-1) = 101.558675
# xi = 3.628947, f(xi) = 43.161593, f'(xi) = 51.996181
# xi+1 = 2.798856, Approximation error = 0.830092, Relative approximation error = 0.296583
# Iteration 11:
# xi-1 = 3.628947, f(xi-1) = 43.161593
# xi = 2.798856, f(xi) = 18.126239, f'(xi) = 30.159749
# xi+1 = 2.197848, Approximation error = 0.601008, Relative approximation error = 0.273453
# Iteration 12:
# xi-1 = 2.798856, f(xi-1) = 18.126239
# xi = 2.197848, f(xi) = 7.418935, f'(xi) = 17.815587
# xi+1 = 1.781419, Approximation error = 0.416429, Relative approximation error = 0.233763
# Iteration 13:
# xi-1 = 2.197848, f(xi-1) = 7.418935
# xi = 1.781419, f(xi) = 2.871828, f'(xi) = 10.919275
# xi+1 = 1.518413, Approximation error = 0.263005, Relative approximation error = 0.173211
# Iteration 14:
# xi-1 = 1.781419, f(xi-1) = 2.871828
# xi = 1.518413, f(xi) = 0.982408, f'(xi) = 7.183960
# xi+1 = 1.381663, Approximation error = 0.136750, Relative approximation error = 0.098975
# Iteration 15:
# xi-1 = 1.518413, f(xi-1) = 0.982408
# xi = 1.381663, f(xi) = 0.255922, f'(xi) = 5.312507
# xi+1 = 1.333490, Approximation error = 0.048173, Relative approximation error = 0.036126
# Iteration 16:
# xi-1 = 1.381663, f(xi-1) = 0.255922
# xi = 1.333490, f(xi) = 0.037714, f'(xi) = 4.529620
# xi+1 = 1.325163, Approximation error = 0.008326, Relative approximation error = 0.006283
# Iteration 17:
# xi-1 = 1.333490, f(xi-1) = 0.037714
# xi = 1.325163, f(xi) = 0.001901, f'(xi) = 4.301344
# xi+1 = 1.324722, Approximation error = 0.000442, Relative approximation error = 0.000334
# Iteration 18:
# xi-1 = 1.325163, f(xi-1) = 0.001901
# xi = 1.324722, f(xi) = 0.000015, f'(xi) = 4.266418
# xi+1 = 1.324718, Approximation error = 0.000004, Relative approximation error = 0.000003
# Iteration 19:
# xi-1 = 1.324722, f(xi-1) = 0.000015
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264647
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
# Iteration 20:
# xi-1 = 1.324718, f(xi-1) = 0.000000
# xi = 1.324718, f(xi) = 0.000000, f'(xi) = 4.264633
# xi+1 = 1.324718, Approximation error = 0.000000, Relative approximation error = 0.000000
